# %%
import matplotlib.pyplot as plt

x = [2, 4, 5]
y = [2, 3, 6]

plt.plot(x, y)

# %%
# !pip install matplotlib # it was shwoing error as module not install so had to use this

# %%
x = [2, 4, 5]
y = [2, 3, 6]

plt.plot(x, y)


plt.xlabel('X Axis')
# Out:
# Text(0.5, 0, 'X Axis')

# %%
x = [2, 4, 5]
y = [2, 3, 6]

plt.plot(x, y)


plt.xlabel('X Axis')

plt.ylabel( 'Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
x = [2, 4, 5]
y = [2, 3, 6]

plt.plot(x, y)


plt.xlabel('X Axis')

plt.ylabel( 'Y Axis')

plt.title('Demo Graph ')
# Out:
# Text(0.5, 1.0, 'Demo Graph ')
